# %% [markdown]
# <a href="https://colab.research.google.com/github/coyens/Python/blob/master/WebScraping/Rossman-robocze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:61.0) Gecko/20100101 Firefox/61.0'}
r = requests.get("https://www.rossmann.pl/drogerie", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})

c = r.content

print(c)
# Out:
# b'<!DOCTYPE html><html lang="pl"><head><link rel="stylesheet" href="/_next/static/css/commons.css"/><meta charSet="UTF-8"/><meta http-equiv="Cache-control" content="public"/><meta name="theme-color" content="#c8102e"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><link rel="SHORTCUT ICON" href="https://www.ros.net.pl/Portals/0/favicon.ico" type="image/x-icon"/><script src="/static/vendor/js/jquery.min.js"></script><script src="/static/vendor/js/jquery.fancybox.min.js"></script><link rel="stylesheet" href="/static/vendor/css/jquery.fancybox.min.css"/><link rel="manifest" href="/manifest.json"/><script type="application/ld+json">{"@context": "https://schema.org", "@type": "WebSite", "name": "Rossmann", "url": "https://www.rossmann.pl/", "potentialAction": {"@type": "SearchAction", "target": "https://www.rossmann.pl/produkty?Search={search_term_string}", "query-input": "requir
# ...

# %%
soup = BeautifulSoup(c, "html.parser")

# %%
print(soup.prettify())

# %%
all =soup.find_all("script",id="__NEXT_DATA__")

# %%
all
# Out:
# [<script id="__NEXT_DATA__" type="application/json">{"dataManager":"[]","props":{"pageProps":{"pageProps":{"metatags":{"title":"Lista drogerii w Polsce | Drogeria Rossmann.pl"}},"reduxStore":{},"initialReduxState":{"appLayout":{"menu":{"data":null,"fetching":false,"intact":true,"error":null},"benefitsHolder":{"data":[{"Id":3,"Html":"\u003cimg src=\"/static/portal/ico-benefit-3.png\" alt=\"\" /\u003e\u003csmall\u003eBezpieczne płatności\u003c/small\u003e"},{"Id":4,"Html":"\u003cimg src=\"/static/portal/ico-benefit-4.png\" alt=\"\"\u003e\u003csmall\u003eZamów i odbierz\u003c/small\u003e"},{"Id":5,"Html":"\u003cimg src=\"/static/portal/ico-benefit-5.png\" alt=\"\"\u003e\u003csmall\u003e1300 punktów odbioru\u003c/small\u003e"}],"fetching":false,"intact":true,"error":null},"basket":{"data":null,"fetching":false,"intact":true,"error":null,"meta":{"total":0,"price":0,"discounts":null,"totalDiscounts":0,"timestamp":0,"needsDiscountRecalc":false}},"loggedBasket":{"data":null,"fetching":false,
# ...

# %%
l=[]
for item in all:
  d={}
  try:
    d["Nazwa"]=item.get("title")
  except:
    d["Nazwa"]=None
  try:
    d["Lat"]=item("Longitude")
  except:
    d["lat"]=None
  try:
    d["Lng"]=item.get["Latitude"]
  except:
    d["Lng"]=None
  l.append(d)

print(l)
#"shops":{"all":{"data":[{"ShopId":2400,"ShippingDesti
#<div class="storelist__item ui-expandable js-accordion-store js-store" data-lat="52.396525" data-lng="20.932849" data-i
#dat = soup.select_one('div[data-lat]')
#print(dat['data-lat'],dat['data-lng'])
# Out:
# [{'Nazwa': None, 'Lat': [], 'Lng': None}]

# %%
all_items = []
html = BeautifulSoup(c, 'html.parser')
timeline = html.select('#timeline li.stream-item')
for item in all:
    tweet_text = item("ShopId")
    all_tweets.append({ "text": tweet_text}) 

print(all_items)
# Out:
# []

# %%
all.get("Latitude")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-7a845f9b0c9d> in <module>()
# ----> 1 all.get("Latitude")
#
# /usr/local/lib/python3.6/dist-packages/bs4/element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'get'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
for item in all:
  lista = []
  lista.append(item.get['Longitude'])
  
print(lista)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-a9d1361ce818> in <module>()
#       1 for item in all:
#       2   lista = []
# ----> 3   lista.append(item.get['Longitude'])
#       4
#       5 print(lista)
#
# TypeError: 'method' object is not subscriptable

# %%
import pandas
df=pandas.DataFrame(l)
print(df)

df.to_csv("Output.csv")

# %%
df

# %%
l=[]
base_url="http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,30,10):
    print("http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=+str(page)"+".html")
    r=requests.get("http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="+str(page)+".html")
    #c=r.json()["list"]
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class":"propertyRow"})
# Out:
# http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=+str(page).html
# http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=+str(page).html
# http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=+str(page).html
